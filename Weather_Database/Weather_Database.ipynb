# %%
#import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates=list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
#import the requests library
import requests
from datetime import datetime

#import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2e671e2b205101b6802253a635b48ef1

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    
    #log the uRL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    #Add 1 to the record count
    record_count+=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = city_weather["dt"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | mahibadhoo
# Processing Record 3 of Set 1 | lekoni
# Processing Record 4 of Set 1 | antofagasta
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | talnakh
# Processing Record 12 of Set 1 | beloha
# Processing Record 13 of Set 1 | lavrentiya
# Processing Record 14 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 15 of Set 1 | umm kaddadah
# Processing Record 16 of Set 1 | viedma
# Processing Record 17 of Set 1 | constitucion
# Processing Record 18 of Set 1 | sawtell
# Processing Record 19 of Set 1 | kilis
# Processing Record 20 of Set 1 | tura
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | beringovskiy
# Processing Record 24 of Set 1 | yarim
# Processing Record 25 of Set 1 | hasaki
# Processing Record 26 of Set 1 | marsa matruh
# Processing Record 27 of Set 1 | alofi
# Processing Record 28 of Set 1 | ancud
# Processing Record 29 of Set 1 | tuatapere
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 1 | kosterevo
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | mehndawal
# Processing Record 40 of Set 1 | yershichi
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 43 of Set 1 | poum
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | guerrero negro
# Processing Record 46 of Set 1 | carauari
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | ous
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | labuhan
# Processing Record 2 of Set 2 | cordele
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | nizwa
# Processing Record 5 of Set 2 | kedgwick
# Processing Record 6 of Set 2 | jiuquan
# Processing Record 7 of Set 2 | paamiut
# Processing Record 8 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | ust-uda
# Processing Record 13 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 2 | plainview
# Processing Record 15 of Set 2 | alyangula
# Processing Record 16 of Set 2 | qunduz
# Processing Record 17 of Set 2 | taoudenni
# Processing Record 18 of Set 2 | provideniya
# Processing Record 19 of Set 2 | waipawa
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | hirara
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | severo-kurilsk
# Processing Record 28 of Set 2 | ler
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | westport
# Processing Record 31 of Set 2 | pisco
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | mount isa
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | hailar
# Processing Record 37 of Set 2 | lompoc
# Processing Record 38 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 2 | lufkin
# Processing Record 40 of Set 2 | raudeberg
# Processing Record 41 of Set 2 | xai-xai
# Processing Record 42 of Set 2 | taitung
# Processing Record 43 of Set 2 | port hardy
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 2 | visby
# Processing Record 47 of Set 2 | arman
# Processing Record 48 of Set 2 | rongcheng
# Processing Record 49 of Set 2 | ilulissat
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | vao
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | vaini
# Processing Record 4 of Set 3 | samarai
# Processing Record 5 of Set 3 | leningradskiy
# Processing Record 6 of Set 3 | poiana blenchii
# Processing Record 7 of Set 3 | dalby
# Processing Record 8 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 9 of Set 3 | ouesso
# Processing Record 10 of Set 3 | nata
# Processing Record 11 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 3 | kara
# Processing Record 13 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | darab
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | norman wells
# Processing Record 19 of Set 3 | geraldton
# Processing Record 20 of Set 3 | horki
# Processing Record 21 of Set 3 | tazovskiy
# Processing Record 22 of Set 3 | pavlodar
# Processing Record 23 of Set 3 | mamallapuram
# Processing Record 24 of Set 3 | cape town
# Processing Record 25 of Set 3 | mapiri
# Processing Record 26 of Set 3 | charters towers
# Processing Record 27 of Set 3 | dzaoudzi
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | broome
# Processing Record 30 of Set 3 | klaksvik
# Processing Record 31 of Set 3 | trindade
# Processing Record 32 of Set 3 | jacmel
# Processing Record 33 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 3 | bengkulu
# Processing Record 35 of Set 3 | jinchang
# Processing Record 36 of Set 3 | trairi
# Processing Record 37 of Set 3 | plotnikovo
# Processing Record 38 of Set 3 | busselton
# Processing Record 39 of Set 3 | elizabeth city
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 3 | tiruvottiyur
# City not found. Skipping...
# Processing Record 45 of Set 3 | jand
# Processing Record 46 of Set 3 | tiksi
# Processing Record 47 of Set 3 | afua
# Processing Record 48 of Set 3 | hithadhoo
# Processing Record 49 of Set 3 | danville
# Processing Record 50 of Set 3 | katsuura
# Processing Record 1 of Set 4 | ramanuj ganj
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | puerto ayora
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | amapa
# Processing Record 7 of Set 4 | beidao
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | pevek
# Processing Record 10 of Set 4 | neiafu
# Processing Record 11 of Set 4 | thompson
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | airai
# Processing Record 14 of Set 4 | ponta do sol
# Processing Record 15 of Set 4 | saint-augustin
# Processing Record 16 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 4 | vestmanna
# Processing Record 18 of Set 4 | te anau
# Processing Record 19 of Set 4 | khani
# Processing Record 20 of Set 4 | kulhudhuffushi
# Processing Record 21 of Set 4 | belmonte
# Processing Record 22 of Set 4 | esso
# Processing Record 23 of Set 4 | lagoa
# Processing Record 24 of Set 4 | tiznit
# Processing Record 25 of Set 4 | plastun
# Processing Record 26 of Set 4 | vilhena
# Processing Record 27 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 4 | pangnirtung
# Processing Record 29 of Set 4 | chifeng
# Processing Record 30 of Set 4 | kavieng
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | clyde river
# Processing Record 33 of Set 4 | port hedland
# Processing Record 34 of Set 4 | chokurdakh
# Processing Record 35 of Set 4 | jinka
# Processing Record 36 of Set 4 | coihaique
# Processing Record 37 of Set 4 | lixourion
# Processing Record 38 of Set 4 | sarab
# Processing Record 39 of Set 4 | hearst
# Processing Record 40 of Set 4 | cayenne
# Processing Record 41 of Set 4 | qaqortoq
# Processing Record 42 of Set 4 | igarape-miri
# City not found. Skipping...
# Processing Record 43 of Set 4 | urumqi
# Processing Record 44 of Set 4 | richards bay
# Processing Record 45 of Set 4 | xining
# Processing Record 46 of Set 4 | baruun-urt
# Processing Record 47 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 4 | los llanos de aridane
# Processing Record 49 of Set 4 | llata
# Processing Record 50 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 5 | colares
# Processing Record 2 of Set 5 | cabedelo
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | altamont
# Processing Record 5 of Set 5 | flin flon
# Processing Record 6 of Set 5 | buchanan
# Processing Record 7 of Set 5 | key west
# Processing Record 8 of Set 5 | ribeira grande
# Processing Record 9 of Set 5 | faya
# Processing Record 10 of Set 5 | praia
# Processing Record 11 of Set 5 | grand gaube
# Processing Record 12 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 5 | bluff
# Processing Record 14 of Set 5 | sisimiut
# Processing Record 15 of Set 5 | palmer
# Processing Record 16 of Set 5 | mangawan
# Processing Record 17 of Set 5 | lorengau
# Processing Record 18 of Set 5 | ginda
# Processing Record 19 of Set 5 | challans
# Processing Record 20 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 5 | pindiga
# Processing Record 22 of Set 5 | kaseda
# Processing Record 23 of Set 5 | anadyr
# Processing Record 24 of Set 5 | byron bay
# Processing Record 25 of Set 5 | bambanglipuro
# Processing Record 26 of Set 5 | gurupa
# Processing Record 27 of Set 5 | saint-philippe
# Processing Record 28 of Set 5 | gat
# Processing Record 29 of Set 5 | luderitz
# Processing Record 30 of Set 5 | el cobre
# Processing Record 31 of Set 5 | esperance
# Processing Record 32 of Set 5 | kita
# Processing Record 33 of Set 5 | tutoia
# Processing Record 34 of Set 5 | tasiilaq
# Processing Record 35 of Set 5 | saint-pierre
# Processing Record 36 of Set 5 | gandai
# Processing Record 37 of Set 5 | san quintin
# Processing Record 38 of Set 5 | tomatlan
# Processing Record 39 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 5 | svit
# Processing Record 41 of Set 5 | anupgarh
# Processing Record 42 of Set 5 | saldanha
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | brigantine
# Processing Record 45 of Set 5 | fereydunshahr
# Processing Record 46 of Set 5 | aklavik
# Processing Record 47 of Set 5 | lata
# Processing Record 48 of Set 5 | muzhi
# Processing Record 49 of Set 5 | puerto leguizamo
# Processing Record 50 of Set 5 | balangir
# Processing Record 1 of Set 6 | robertsganj
# Processing Record 2 of Set 6 | itamaraju
# Processing Record 3 of Set 6 | torbay
# Processing Record 4 of Set 6 | stettler
# Processing Record 5 of Set 6 | bathsheba
# Processing Record 6 of Set 6 | donzdorf
# Processing Record 7 of Set 6 | houma
# Processing Record 8 of Set 6 | nchelenge
# Processing Record 9 of Set 6 | zhanakorgan
# Processing Record 10 of Set 6 | djenne
# Processing Record 11 of Set 6 | nioro
# Processing Record 12 of Set 6 | jejuri
# Processing Record 13 of Set 6 | astoria
# Processing Record 14 of Set 6 | chuy
# Processing Record 15 of Set 6 | san jose
# Processing Record 16 of Set 6 | omboue
# Processing Record 17 of Set 6 | tlahualilo
# City not found. Skipping...
# Processing Record 18 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 6 | ulaangom
# Processing Record 20 of Set 6 | mount pleasant
# Processing Record 21 of Set 6 | ugoofaaru
# Processing Record 22 of Set 6 | nouna
# Processing Record 23 of Set 6 | shenjiamen
# Processing Record 24 of Set 6 | portland
# Processing Record 25 of Set 6 | leh
# Processing Record 26 of Set 6 | ilhabela
# Processing Record 27 of Set 6 | ribas do rio pardo
# Processing Record 28 of Set 6 | garmsar
# Processing Record 29 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 30 of Set 6 | vadso
# Processing Record 31 of Set 6 | rena
# Processing Record 32 of Set 6 | saint anthony
# Processing Record 33 of Set 6 | panjab
# Processing Record 34 of Set 6 | bitam
# Processing Record 35 of Set 6 | itarema
# Processing Record 36 of Set 6 | yurgamysh
# Processing Record 37 of Set 6 | kyren
# Processing Record 38 of Set 6 | tanout
# Processing Record 39 of Set 6 | den helder
# Processing Record 40 of Set 6 | suntar
# Processing Record 41 of Set 6 | port keats
# Processing Record 42 of Set 6 | bubaque
# Processing Record 43 of Set 6 | kungurtug
# Processing Record 44 of Set 6 | yumen
# Processing Record 45 of Set 6 | goundi
# Processing Record 46 of Set 6 | verkh-usugli
# Processing Record 47 of Set 6 | puerto del rosario
# Processing Record 48 of Set 6 | port shepstone
# Processing Record 49 of Set 6 | kysyl-syr
# Processing Record 50 of Set 6 | tuktoyaktuk
# Processing Record 1 of Set 7 | pacific grove
# Processing Record 2 of Set 7 | kalmunai
# Processing Record 3 of Set 7 | barrow
# Processing Record 4 of Set 7 | wanning
# Processing Record 5 of Set 7 | naze
# Processing Record 6 of Set 7 | cuauhtemoc
# Processing Record 7 of Set 7 | ostrovnoy
# Processing Record 8 of Set 7 | lebork
# Processing Record 9 of Set 7 | presidencia roque saenz pena
# Processing Record 10 of Set 7 | yurty
# Processing Record 11 of Set 7 | emerald
# Processing Record 12 of Set 7 | lalmohan
# Processing Record 13 of Set 7 | teknaf
# Processing Record 14 of Set 7 | hami
# Processing Record 15 of Set 7 | lusambo
# Processing Record 16 of Set 7 | fort saint james
# Processing Record 17 of Set 7 | kununurra
# Processing Record 18 of Set 7 | dukat
# Processing Record 19 of Set 7 | golkoy
# Processing Record 20 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 21 of Set 7 | sola
# Processing Record 22 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 23 of Set 7 | darhan
# Processing Record 24 of Set 7 | sorland
# Processing Record 25 of Set 7 | leshan
# Processing Record 26 of Set 7 | fairbanks
# Processing Record 27 of Set 7 | maryville
# Processing Record 28 of Set 7 | kwinana
# Processing Record 29 of Set 7 | katangli
# Processing Record 30 of Set 7 | sava
# Processing Record 31 of Set 7 | pandan
# Processing Record 32 of Set 7 | ahipara
# Processing Record 33 of Set 7 | hualmay
# Processing Record 34 of Set 7 | vytegra
# Processing Record 35 of Set 7 | russell
# Processing Record 36 of Set 7 | laguna
# Processing Record 37 of Set 7 | nyurba
# Processing Record 38 of Set 7 | mitsamiouli
# Processing Record 39 of Set 7 | sabla
# Processing Record 40 of Set 7 | pryazha
# Processing Record 41 of Set 7 | coquimbo
# Processing Record 42 of Set 7 | ucluelet
# Processing Record 43 of Set 7 | vanavara
# Processing Record 44 of Set 7 | merzifon
# Processing Record 45 of Set 7 | bredasdorp
# Processing Record 46 of Set 7 | faanui
# Processing Record 47 of Set 7 | salinopolis
# Processing Record 48 of Set 7 | souillac
# Processing Record 49 of Set 7 | chenzhou
# Processing Record 50 of Set 7 | san juan
# Processing Record 1 of Set 8 | ambilobe
# Processing Record 2 of Set 8 | hervey bay
# Processing Record 3 of Set 8 | aras
# Processing Record 4 of Set 8 | gizo
# Processing Record 5 of Set 8 | manokwari
# Processing Record 6 of Set 8 | buraydah
# Processing Record 7 of Set 8 | tuensang
# Processing Record 8 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 8 | burica
# City not found. Skipping...
# Processing Record 10 of Set 8 | pingyin
# Processing Record 11 of Set 8 | prince rupert
# Processing Record 12 of Set 8 | acapulco
# Processing Record 13 of Set 8 | egvekinot
# Processing Record 14 of Set 8 | maniitsoq
# Processing Record 15 of Set 8 | novooleksiyivka
# Processing Record 16 of Set 8 | chicama
# Processing Record 17 of Set 8 | warrington
# Processing Record 18 of Set 8 | novikovo
# Processing Record 19 of Set 8 | zyryanka
# Processing Record 20 of Set 8 | soyo
# Processing Record 21 of Set 8 | spokane
# Processing Record 22 of Set 8 | ati
# Processing Record 23 of Set 8 | carupano
# Processing Record 24 of Set 8 | tete
# Processing Record 25 of Set 8 | pathein
# Processing Record 26 of Set 8 | port-gentil
# Processing Record 27 of Set 8 | ketchikan
# Processing Record 28 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 29 of Set 8 | garlasco
# Processing Record 30 of Set 8 | green river
# Processing Record 31 of Set 8 | sitka
# Processing Record 32 of Set 8 | sutysky
# Processing Record 33 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 8 | jacareacanga
# Processing Record 35 of Set 8 | wanaka
# Processing Record 36 of Set 8 | juegang
# Processing Record 37 of Set 8 | anloga
# Processing Record 38 of Set 8 | benjamin hill
# Processing Record 39 of Set 8 | zhuanghe
# Processing Record 40 of Set 8 | luganville
# Processing Record 41 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 8 | iquique
# Processing Record 43 of Set 8 | batemans bay
# Processing Record 44 of Set 8 | sigulda
# Processing Record 45 of Set 8 | littleton
# Processing Record 46 of Set 8 | nogliki
# Processing Record 47 of Set 8 | ternate
# Processing Record 48 of Set 8 | sayyan
# Processing Record 49 of Set 8 | atar
# Processing Record 50 of Set 8 | vanimo
# Processing Record 1 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 9 | chokwe
# Processing Record 3 of Set 9 | kamenka
# Processing Record 4 of Set 9 | forio
# Processing Record 5 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 6 of Set 9 | las cruces
# Processing Record 7 of Set 9 | beian
# Processing Record 8 of Set 9 | khasan
# Processing Record 9 of Set 9 | monterey
# Processing Record 10 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 11 of Set 9 | la ronge
# Processing Record 12 of Set 9 | inhambane
# Processing Record 13 of Set 9 | kletskaya
# Processing Record 14 of Set 9 | changli
# Processing Record 15 of Set 9 | high level
# Processing Record 16 of Set 9 | dyurtyuli
# Processing Record 17 of Set 9 | roquetas de mar
# Processing Record 18 of Set 9 | maseru
# Processing Record 19 of Set 9 | nadaun
# Processing Record 20 of Set 9 | ino
# Processing Record 21 of Set 9 | indianola
# Processing Record 22 of Set 9 | balassagyarmat
# Processing Record 23 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 9 | mantua
# Processing Record 25 of Set 9 | hondo
# Processing Record 26 of Set 9 | mitu
# Processing Record 27 of Set 9 | baiyin
# Processing Record 28 of Set 9 | lat yao
# Processing Record 29 of Set 9 | vila velha
# Processing Record 30 of Set 9 | neftegorsk
# Processing Record 31 of Set 9 | arys
# Processing Record 32 of Set 9 | gunjur
# Processing Record 33 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 9 | meulaboh
# Processing Record 35 of Set 9 | nosy varika
# Processing Record 36 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 9 | tommot
# Processing Record 38 of Set 9 | buka
# Processing Record 39 of Set 9 | talcahuano
# Processing Record 40 of Set 9 | eureka
# Processing Record 41 of Set 9 | sogne
# Processing Record 42 of Set 9 | sumenep
# Processing Record 43 of Set 9 | half moon bay
# Processing Record 44 of Set 9 | amot
# Processing Record 45 of Set 9 | hofn
# Processing Record 46 of Set 9 | dengzhou
# Processing Record 47 of Set 9 | panguna
# Processing Record 48 of Set 9 | melilla
# Processing Record 49 of Set 9 | brae
# Processing Record 50 of Set 9 | abha
# Processing Record 1 of Set 10 | tsumeb
# Processing Record 2 of Set 10 | uruzgan
# Processing Record 3 of Set 10 | erenhot
# Processing Record 4 of Set 10 | gambela
# Processing Record 5 of Set 10 | valdosta
# Processing Record 6 of Set 10 | canmore
# Processing Record 7 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 10 | kuminskiy
# Processing Record 9 of Set 10 | kenai
# Processing Record 10 of Set 10 | olinda
# Processing Record 11 of Set 10 | kerema
# Processing Record 12 of Set 10 | worland
# Processing Record 13 of Set 10 | kholtoson
# Processing Record 14 of Set 10 | longkou
# Processing Record 15 of Set 10 | kabanjahe
# Processing Record 16 of Set 10 | kidal
# Processing Record 17 of Set 10 | valdivia
# Processing Record 18 of Set 10 | boa vista
# Processing Record 19 of Set 10 | vestmannaeyjar
# Processing Record 20 of Set 10 | nouadhibou
# Processing Record 21 of Set 10 | aleksandrovsk
# Processing Record 22 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 10 | the valley
# Processing Record 24 of Set 10 | cockburn town
# Processing Record 25 of Set 10 | twin falls
# Processing Record 26 of Set 10 | lermontovka
# Processing Record 27 of Set 10 | port blair
# Processing Record 28 of Set 10 | bose
# Processing Record 29 of Set 10 | muriti
# Processing Record 30 of Set 10 | pafos
# Processing Record 31 of Set 10 | jiwani
# Processing Record 32 of Set 10 | laje
# Processing Record 33 of Set 10 | baependi
# Processing Record 34 of Set 10 | xiongzhou
# Processing Record 35 of Set 10 | cowra
# Processing Record 36 of Set 10 | juan aldama
# Processing Record 37 of Set 10 | ayan
# Processing Record 38 of Set 10 | college
# Processing Record 39 of Set 10 | severo-yeniseyskiy
# Processing Record 40 of Set 10 | panzhihua
# Processing Record 41 of Set 10 | araguaina
# Processing Record 42 of Set 10 | sistranda
# Processing Record 43 of Set 10 | homer
# Processing Record 44 of Set 10 | lasa
# Processing Record 45 of Set 10 | san patricio
# Processing Record 46 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 10 | pedana
# Processing Record 48 of Set 10 | kahului
# Processing Record 49 of Set 10 | batagay-alyta
# Processing Record 50 of Set 10 | touros
# Processing Record 1 of Set 11 | robertsport
# Processing Record 2 of Set 11 | havelock
# Processing Record 3 of Set 11 | ostersund
# Processing Record 4 of Set 11 | kendari
# Processing Record 5 of Set 11 | olafsvik
# Processing Record 6 of Set 11 | patnos
# Processing Record 7 of Set 11 | shahpura
# Processing Record 8 of Set 11 | vardo
# Processing Record 9 of Set 11 | fenoarivo
# Processing Record 10 of Set 11 | chapais
# Processing Record 11 of Set 11 | sao filipe
# Processing Record 12 of Set 11 | carrollton
# Processing Record 13 of Set 11 | mazyr
# Processing Record 14 of Set 11 | alekseyevsk
# Processing Record 15 of Set 11 | hamilton
# Processing Record 16 of Set 11 | isangel
# Processing Record 17 of Set 11 | nadym
# Processing Record 18 of Set 11 | port lincoln
# Processing Record 19 of Set 11 | burnie
# Processing Record 20 of Set 11 | fortuna
# Processing Record 21 of Set 11 | ariquemes
# Processing Record 22 of Set 11 | trelew
# Processing Record 23 of Set 11 | urengoy
# Processing Record 24 of Set 11 | huilong
# Processing Record 25 of Set 11 | yar-sale
# Processing Record 26 of Set 11 | sao joao da barra
# Processing Record 27 of Set 11 | aloleng
# Processing Record 28 of Set 11 | yerbogachen
# Processing Record 29 of Set 11 | masvingo
# Processing Record 30 of Set 11 | tandil
# Processing Record 31 of Set 11 | gilbues
# Processing Record 32 of Set 11 | rocha
# Processing Record 33 of Set 11 | groa
# Processing Record 34 of Set 11 | nome
# Processing Record 35 of Set 11 | semnan
# Processing Record 36 of Set 11 | harper
# Processing Record 37 of Set 11 | hambantota
# Processing Record 38 of Set 11 | west plains
# Processing Record 39 of Set 11 | yatou
# Processing Record 40 of Set 11 | kawalu
# Processing Record 41 of Set 11 | poronaysk
# Processing Record 42 of Set 11 | dickinson
# Processing Record 43 of Set 11 | gigmoto
# Processing Record 44 of Set 11 | pochutla
# Processing Record 45 of Set 11 | energetik
# Processing Record 46 of Set 11 | nanortalik
# Processing Record 47 of Set 11 | mutis
# Processing Record 48 of Set 11 | dnipryany
# Processing Record 49 of Set 11 | yilan
# Processing Record 50 of Set 11 | tautira
# Processing Record 1 of Set 12 | grindavik
# Processing Record 2 of Set 12 | karacakoy
# Processing Record 3 of Set 12 | mount gambier
# Processing Record 4 of Set 12 | abu samrah
# Processing Record 5 of Set 12 | tigil
# Processing Record 6 of Set 12 | filadelfia
# Processing Record 7 of Set 12 | escanaba
# Processing Record 8 of Set 12 | vila franca do campo
# Processing Record 9 of Set 12 | nyagan
# Processing Record 10 of Set 12 | road town
# Processing Record 11 of Set 12 | xichang
# Processing Record 12 of Set 12 | palaikastron
# Processing Record 13 of Set 12 | kilemary
# Processing Record 14 of Set 12 | envira
# Processing Record 15 of Set 12 | goryachiy klyuch
# Processing Record 16 of Set 12 | jumla
# Processing Record 17 of Set 12 | teahupoo
# Processing Record 18 of Set 12 | coruripe
# Processing Record 19 of Set 12 | lazaro cardenas
# Processing Record 20 of Set 12 | husavik
# Processing Record 21 of Set 12 | moerai
# Processing Record 22 of Set 12 | gorom-gorom
# Processing Record 23 of Set 12 | breytovo
# Processing Record 24 of Set 12 | solnechnyy
# Processing Record 25 of Set 12 | zemlyansk
# Processing Record 26 of Set 12 | kosmach
# Processing Record 27 of Set 12 | novolabinskaya
# Processing Record 28 of Set 12 | miranda
# Processing Record 29 of Set 12 | northam
# Processing Record 30 of Set 12 | kaspiyskiy
# Processing Record 31 of Set 12 | piuma
# Processing Record 32 of Set 12 | berea
# Processing Record 33 of Set 12 | umm lajj
# Processing Record 34 of Set 12 | pacasmayo
# Processing Record 35 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 12 | daru
# Processing Record 37 of Set 12 | palu
# Processing Record 38 of Set 12 | sechura
# Processing Record 39 of Set 12 | medina
# Processing Record 40 of Set 12 | los chiles
# Processing Record 41 of Set 12 | freeport
# Processing Record 42 of Set 12 | biak
# Processing Record 43 of Set 12 | yabassi
# Processing Record 44 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 12 | preobrazheniye
# Processing Record 46 of Set 12 | moron
# Processing Record 47 of Set 12 | gisborne
# Processing Record 48 of Set 12 | shenkursk
# Processing Record 49 of Set 12 | whyalla
# Processing Record 50 of Set 12 | fare
# Processing Record 1 of Set 13 | sandwick
# Processing Record 2 of Set 13 | katobu
# Processing Record 3 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 13 | kupang
# Processing Record 5 of Set 13 | gap
# Processing Record 6 of Set 13 | chik
# Processing Record 7 of Set 13 | kiama
# Processing Record 8 of Set 13 | ambon
# Processing Record 9 of Set 13 | shihezi
# Processing Record 10 of Set 13 | felipe carrillo puerto
# Processing Record 11 of Set 13 | saint-denis
# Processing Record 12 of Set 13 | ferrol
# Processing Record 13 of Set 13 | angoram
# Processing Record 14 of Set 13 | dubbo
# Processing Record 15 of Set 13 | muros
# Processing Record 16 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 13 | san francisco
# Processing Record 18 of Set 13 | narsaq
# Processing Record 19 of Set 13 | deputatskiy
# Processing Record 20 of Set 13 | venado tuerto
# Processing Record 21 of Set 13 | nizhniy tsasuchey
# Processing Record 22 of Set 13 | dillon
# Processing Record 23 of Set 13 | padang
# Processing Record 24 of Set 13 | maneadero
# Processing Record 25 of Set 13 | caluquembe
# Processing Record 26 of Set 13 | kattivakkam
# Processing Record 27 of Set 13 | la libertad
# Processing Record 28 of Set 13 | mercedes
# Processing Record 29 of Set 13 | atambua
# Processing Record 30 of Set 13 | taikang
# Processing Record 31 of Set 13 | utete
# Processing Record 32 of Set 13 | flinders
# Processing Record 33 of Set 13 | wagar
# Processing Record 34 of Set 13 | paytug
# City not found. Skipping...
# Processing Record 35 of Set 13 | ribeirao branco
# Processing Record 36 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 13 | benghazi
# Processing Record 38 of Set 13 | sao felix do xingu
# Processing Record 39 of Set 13 | sinop
# Processing Record 40 of Set 13 | bolobo
# Processing Record 41 of Set 13 | livingston
# Processing Record 42 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 13 | sao geraldo do araguaia
# Processing Record 44 of Set 13 | hirado
# Processing Record 45 of Set 13 | camacha
# Processing Record 46 of Set 13 | kokstad
# Processing Record 47 of Set 13 | sembakung
# Processing Record 48 of Set 13 | nampula
# Processing Record 49 of Set 13 | ust-tsilma
# Processing Record 50 of Set 13 | honiara
# Processing Record 1 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 2 of Set 14 | barotac nuevo
# Processing Record 3 of Set 14 | aksu
# Processing Record 4 of Set 14 | voyvozh
# Processing Record 5 of Set 14 | shingu
# Processing Record 6 of Set 14 | moyale
# Processing Record 7 of Set 14 | kirishi
# Processing Record 8 of Set 14 | chulman
# Processing Record 9 of Set 14 | dingle
# Processing Record 10 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 14 | gafargaon
# Processing Record 12 of Set 14 | ayna
# Processing Record 13 of Set 14 | la tuque
# Processing Record 14 of Set 14 | manggar
# Processing Record 15 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 17 of Set 14 | dunedin
# Processing Record 18 of Set 14 | xuddur
# Processing Record 19 of Set 14 | sobolevo
# Processing Record 20 of Set 14 | iwanai
# Processing Record 21 of Set 14 | nauta
# Processing Record 22 of Set 14 | susanville
# Processing Record 23 of Set 14 | chimore
# Processing Record 24 of Set 14 | aykhal
# Processing Record 25 of Set 14 | murray
# Processing Record 26 of Set 14 | komsomolskiy
# Processing Record 27 of Set 14 | sinnamary
# Processing Record 28 of Set 14 | hachinohe
# Processing Record 29 of Set 14 | san-pedro
# Processing Record 30 of Set 14 | virginia beach
# Processing Record 31 of Set 14 | ebeltoft
# Processing Record 32 of Set 14 | newport
# Processing Record 33 of Set 14 | nevsehir
# Processing Record 34 of Set 14 | svetlyy
# Processing Record 35 of Set 14 | smithers
# Processing Record 36 of Set 14 | boralday
# Processing Record 37 of Set 14 | macenta
# Processing Record 38 of Set 14 | kyabe
# Processing Record 39 of Set 14 | kargasok
# Processing Record 40 of Set 14 | muroto
# Processing Record 41 of Set 14 | ha giang
# Processing Record 42 of Set 14 | portel
# Processing Record 43 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 44 of Set 14 | mahon
# Processing Record 45 of Set 14 | zaozerne
# Processing Record 46 of Set 14 | brasilia de minas
# Processing Record 47 of Set 14 | kiboga
# Processing Record 48 of Set 14 | aksarka
# Processing Record 49 of Set 14 | yarada
# Processing Record 50 of Set 14 | balabac
# Processing Record 1 of Set 15 | aurangabad
# Processing Record 2 of Set 15 | middle island
# Processing Record 3 of Set 15 | sibolga
# Processing Record 4 of Set 15 | riyadh
# Processing Record 5 of Set 15 | superior
# Processing Record 6 of Set 15 | valkeakoski
# Processing Record 7 of Set 15 | gravdal
# Processing Record 8 of Set 15 | ekibastuz
# Processing Record 9 of Set 15 | maceio
# Processing Record 10 of Set 15 | diapaga
# Processing Record 11 of Set 15 | makakilo city
# Processing Record 12 of Set 15 | juneau
# Processing Record 13 of Set 15 | poya
# Processing Record 14 of Set 15 | upata
# Processing Record 15 of Set 15 | kalabo
# Processing Record 16 of Set 15 | ko samui
# Processing Record 17 of Set 15 | pori
# Processing Record 18 of Set 15 | suez
# Processing Record 19 of Set 15 | lafayette
# Processing Record 20 of Set 15 | asau
# Processing Record 21 of Set 15 | urcos
# Processing Record 22 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 23 of Set 15 | north augusta
# Processing Record 24 of Set 15 | menongue
# Processing Record 25 of Set 15 | hovd
# Processing Record 26 of Set 15 | bairiki
# Processing Record 27 of Set 15 | bitung
# Processing Record 28 of Set 15 | slave lake
# Processing Record 29 of Set 15 | sinjar
# Processing Record 30 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 15 | finschhafen
# Processing Record 32 of Set 15 | fomboni
# Processing Record 33 of Set 15 | marienburg
# Processing Record 34 of Set 15 | kousseri
# Processing Record 35 of Set 15 | amahai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     khatanga  71.9667  102.5000     -1.71        97          99        6.78
# 1   mahibadhoo   3.7833   72.9667     82.08        72          97       10.11
# 2       lekoni  -1.5843   14.2591     83.55        56          43        0.96
# 3  antofagasta -23.6500  -70.4000     71.01        60           0       11.50
# 4    upernavik  72.7868  -56.1549    -15.54        74          80        2.66
# 5      qaanaaq  77.4840  -69.3632    -14.94        78          33        3.00
# 6       castro -24.7911  -50.0119     76.32        67          36        6.62
# 7      talnakh  69.4865   88.3972    -11.88        96          52        2.66
# 8       beloha -25.1667   45.0500     72.07        81          36        4.41
# 9   lavrentiya  65.5833 -171.0000      4.57        95         100       18.25
#
#   Country        Date
# 0      RU  1616954447
# 1      MV  1616954448
# 2      GA  1616953855
# 3      CL  1616953762
# 4      GL  1616954449
# 5      GL  1616954449
# 6      BR  1616954450
# 7      RU  1616954450
# 8      MG  1616954450
# 9      RU  1616953675

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ['City', 'Country', 'Lat','Lng','Max Temp','Humidity','Cloudiness', 'Wind Speed'] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     khatanga      RU  71.9667  102.5000     -1.71        97          99
# 1   mahibadhoo      MV   3.7833   72.9667     82.08        72          97
# 2       lekoni      GA  -1.5843   14.2591     83.55        56          43
# 3  antofagasta      CL -23.6500  -70.4000     71.01        60           0
# 4    upernavik      GL  72.7868  -56.1549    -15.54        74          80
# 5      qaanaaq      GL  77.4840  -69.3632    -14.94        78          33
# 6       castro      BR -24.7911  -50.0119     76.32        67          36
# 7      talnakh      RU  69.4865   88.3972    -11.88        96          52
# 8       beloha      MG -25.1667   45.0500     72.07        81          36
# 9   lavrentiya      RU  65.5833 -171.0000      4.57        95         100
#
#    Wind Speed
# 0        6.78
# 1       10.11
# 2        0.96
# 3       11.50
# 4        2.66
# 5        3.00
# 6        6.62
# 7        2.66
# 8        4.41
# 9       18.25

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
